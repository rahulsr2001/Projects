# %% [markdown]
# # WEATHER_CLASSIFICATION

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Asus\Downloads\weather_classification_data.csv')

# %% [markdown]
# # DATA ANALYSING

# %%
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 13195         10.0        74        14.5               71.0       overcast
# 13196         -1.0        76         3.5               23.0         cloudy
# 13197         30.0        77         5.5               28.0       overcast
# 13198          3.0        76        10.0               94.0       overcast
# 13199         -5.0        38         0.0               92.0       overcast
#
# ...

# %%
df.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0         14.0        73         9.5               82.0  partly cloudy
# 1         39.0        96         8.5               71.0  partly cloudy
# 2         30.0        64         7.0               16.0          clear
# 3         38.0        83         1.5               82.0          clear
# 4         27.0        74        17.0               66.0       overcast
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2  Winter              3.5    inland
# 1               1011.43         7  Spring             10.0    inland
# 2               1018.72         5  Spring              5.5  mountain
# 3               1026.25         7  Spring              1.0   coastal
# 4                990.67         1  Winter              2.5  mountain
#
#   Weather Type
# 0        Rainy
# 1       Cloudy
# 2        Sunny
# 3        Sunny
# 4        Rainy

# %%
df.tail()
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%) Cloud Cover  \
# 13195         10.0        74        14.5               71.0    overcast
# 13196         -1.0        76         3.5               23.0      cloudy
# 13197         30.0        77         5.5               28.0    overcast
# 13198          3.0        76        10.0               94.0    overcast
# 13199         -5.0        38         0.0               92.0    overcast
#
#        Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 13195               1003.15         1  Summer              1.0  mountain
# 13196               1067.23         1  Winter              6.0   coastal
# 13197               1012.69         3  Autumn              9.0   coastal
# 13198                984.27         0  Winter              2.0    inland
# 13199               1015.37         5  Autumn             10.0  mountain
#
#       Weather Type
# 13195        Rainy
# 13196        Snowy
# 13197       Cloudy
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Temperature           13200 non-null  float64
#  1   Humidity              13200 non-null  int64
#  2   Wind Speed            13200 non-null  float64
#  3   Precipitation (%)     13200 non-null  float64
#  4   Cloud Cover           13200 non-null  object
#  5   Atmospheric Pressure  13200 non-null  float64
#  6   UV Index              13200 non-null  int64
#  7   Season                13200 non-null  object
#  8   Visibility (km)       13200 non-null  float64
#  9   Location              13200 non-null  object
#  10  Weather Type          13200 non-null  object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind Speed', 'Precipitation (%)',
#        'Cloud Cover', 'Atmospheric Pressure', 'UV Index', 'Season',
#        'Visibility (km)', 'Location', 'Weather Type'],
#       dtype='object')

# %%
df.shape
# Out:
# (13200, 11)

# %%
df.dtypes
# Out:
# Temperature             float64
# Humidity                  int64
# Wind Speed              float64
# Precipitation (%)       float64
# Cloud Cover              object
# Atmospheric Pressure    float64
# UV Index                  int64
# Season                   object
# Visibility (km)         float64
# Location                 object
# Weather Type             object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Temperature             0
# Humidity                0
# Wind Speed              0
# Precipitation (%)       0
# Cloud Cover             0
# Atmospheric Pressure    0
# UV Index                0
# Season                  0
# Visibility (km)         0
# Location                0
# Weather Type            0
# dtype: int64

# %%
graph=df.select_dtypes(include=['float'])
graph
# Out:
#        Temperature  Wind Speed  Precipitation (%)  Atmospheric Pressure  \
# 0             14.0         9.5               82.0               1010.82
# 1             39.0         8.5               71.0               1011.43
# 2             30.0         7.0               16.0               1018.72
# 3             38.0         1.5               82.0               1026.25
# 4             27.0        17.0               66.0                990.67
# ...            ...         ...                ...                   ...
# 13195         10.0        14.5               71.0               1003.15
# 13196         -1.0         3.5               23.0               1067.23
# 13197         30.0         5.5               28.0               1012.69
# 13198          3.0        10.0               94.0                984.27
# 13199         -5.0         0.0               92.0               1015.37
#
#        Visibility (km)
# 0                  3.5
# 1                 10.0
# 2                  5.5
# ...

# %%
graph.hist(figsize=(20,15));

# %% [markdown]
# # DATA CLEANING

# %%
plt.boxplot(df['Temperature'])
plt.title('boxplot of Temperature')
# Out:
# Text(0.5, 1.0, 'boxplot of Temperature')

# %%
plt.boxplot(df['Visibility (km)'])
plt.title('boxplot of Visibility (km)')
# Out:
# Text(0.5, 1.0, 'boxplot of Visibility (km)')

# %%
Q1=np.percentile(df['Temperature'],25,interpolation='midpoint')
Q2=np.percentile(df['Temperature'],50,interpolation='midpoint')
Q3=np.percentile(df['Temperature'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 4.0
# 21.0
# 31.0

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 27.0

# %%
upper_limit=Q3+1.5*IQR
lower_limit=Q1-1.5*IQR
print(upper_limit)
print(lower_limit)
# Out:
# 71.5
# -36.5

# %%
outlier=[]
for x in df['Temperature']:
  if((x>upper_limit) or (x<lower_limit)):
    outlier.append(x)
outlier
# Out:
# [78.0,
#  73.0,
#  80.0,
#  74.0,
#  76.0,
#  91.0,
#  82.0,
#  76.0,
#  77.0,
#  73.0,
#  72.0,
#  72.0,
#  76.0,
#  107.0,
#  75.0,
#  85.0,
#  97.0,
#  84.0,
#  84.0,
#  76.0,
#  76.0,
#  75.0,
#  92.0,
#  72.0,
#  73.0,
#  77.0,
#  85.0,
#  80.0,
#  81.0,
#  109.0,
#  98.0,
#  92.0,
#  75.0,
#  94.0,
#  97.0,
#  78.0,
#  73.0,
#  84.0,
#  90.0,
#  75.0,
#  73.0,
#  72.0,
#  90.0,
#  91.0,
#  91.0,
#  81.0,
#  88.0,
#  99.0,
#  76.0,
#  75.0,
#  77.0,
#  74.0,
#  76.0,
#  99.0,
#  77.0,
#  100.0,
#  74.0,
#  89.0,
#  80.0,
#  107.0,
#  82.0,
#  75.0,
#  82.0,
#  73.0,
#  102.0,
#  72.0,
#  76.0,
#  84.0,
#  72.0,
#  80.0,
#  75.0,
#  73.0,
#  80.0,
#  86.0,
#  90.0,
#  94.0,
#  108.0,
#  77.0,
#  73.0,
#  82.0,
#  75.0,
#  76.0,
#  77.0,
#  87.0,
#  76.0,
#  82.0,
#  77.0,
#  90.0,
#  72.0,
#  95.0,
#  97.0,
#  81.0]

# %%
df1=df['Temperature']>upper_limit
df1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13195    False
# 13196    False
# 13197    False
# 13198    False
# 13199    False
# Name: Temperature, Length: 13200, dtype: bool

# %%
df.loc[df1]
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 210           78.0        81         8.0               78.0       overcast
# 228           73.0        82        47.0              107.0       overcast
# 535           80.0        76         3.0               93.0          clear
# 709           74.0       101        18.0               76.0  partly cloudy
# 730           76.0        91        13.5               82.0  partly cloudy
# ...            ...       ...         ...                ...            ...
# 12752         90.0        83        15.0               98.0          clear
# 12814         72.0        88        12.0               83.0          clear
# 12878         95.0        96         1.0               84.0  partly cloudy
# 13065         97.0        95         7.5               79.0          clear
# 13108         81.0        81        10.5               96.0          clear
#
# ...

# %%
df.loc[df1].index
# Out:
# Index([  210,   228,   535,   709,   730,   881,   886,  1206,  1207,  1313,
#         1704,  1757,  2936,  2958,  3353,  3389,  3489,  3515,  3702,  3734,
#         3908,  3971,  4274,  4449,  4470,  4581,  4915,  5030,  5082,  5085,
#         5382,  5458,  5527,  5766,  5875,  5982,  6155,  6315,  6377,  6426,
#         6448,  6688,  6780,  7019,  7233,  7291,  7303,  7662,  7670,  7682,
#         7892,  7928,  7977,  7979,  8070,  8214,  8280,  8295,  8323,  8353,
#         8638,  8777,  8820,  9224,  9328,  9370,  9562,  9827, 10116, 10140,
#        10188, 10253, 10507, 10652, 10753, 10982, 10993, 11046, 11416, 11428,
#        11557, 11572, 11918, 12192, 12276, 12320, 12410, 12752, 12814, 12878,
#        13065, 13108],
#       dtype='int64')

# %%
df.drop([ 210,   228,   535,   709,   730,   881,   886,  1206,  1207,  1313,
        1704,  1757,  2936,  2958,  3353,  3389,  3489,  3515,  3702,  3734,
        3908,  3971,  4274,  4449,  4470,  4581,  4915,  5030,  5082,  5085,
        5382,  5458,  5527,  5766,  5875,  5982,  6155,  6315,  6377,  6426,
        6448,  6688,  6780,  7019,  7233,  7291,  7303,  7662,  7670,  7682,
        7892,  7928,  7977,  7979,  8070,  8214,  8280,  8295,  8323,  8353,
        8638,  8777,  8820,  9224,  9328,  9370,  9562,  9827, 10116, 10140,
       10188, 10253, 10507, 10652, 10753, 10982, 10993, 11046, 11416, 11428,
       11557, 11572, 11918, 12192, 12276, 12320, 12410, 12752, 12814, 12878,
       13065, 13108],inplace=True)

# %%
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 13195         10.0        74        14.5               71.0       overcast
# 13196         -1.0        76         3.5               23.0         cloudy
# 13197         30.0        77         5.5               28.0       overcast
# 13198          3.0        76        10.0               94.0       overcast
# 13199         -5.0        38         0.0               92.0       overcast
#
# ...

# %%
Q1=np.percentile(df['Visibility (km)'],25,interpolation='midpoint')
Q2=np.percentile(df['Visibility (km)'],50,interpolation='midpoint')
Q3=np.percentile(df['Visibility (km)'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 3.0
# 5.0
# 7.5

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 4.5

# %%
upper_limit=Q3+1.5*IQR
lower_limit=Q1-1.5*IQR
print(upper_limit)
print(lower_limit)
# Out:
# 14.25
# -3.75

# %%
outlier=[]
for i in df['Visibility (km)']:
    if((i>upper_limit)or(i<lower_limit)):
        outlier.append(i)
outlier
# Out:
# [16.5,
#  17.5,
#  17.0,
#  17.0,
#  16.0,
#  18.0,
#  17.0,
#  19.0,
#  16.0,
#  16.5,
#  18.5,
#  15.5,
#  16.0,
#  18.0,
#  16.5,
#  19.0,
#  15.0,
#  19.0,
#  18.0,
#  15.0,
#  18.5,
#  17.0,
#  15.0,
#  16.5,
#  19.0,
#  14.5,
#  16.0,
#  17.0,
#  17.0,
#  15.0,
#  16.5,
#  16.0,
#  16.0,
#  17.0,
#  16.5,
#  19.0,
#  19.0,
#  19.0,
#  16.5,
#  16.0,
#  15.0,
#  16.5,
#  15.0,
#  15.5,
#  16.5,
#  19.0,
#  18.0,
#  17.5,
#  20.0,
#  17.0,
#  15.5,
#  16.5,
#  17.0,
#  16.5,
#  19.0,
#  14.5,
#  17.5,
#  18.5,
#  15.0,
#  14.5,
#  14.5,
#  17.0,
#  18.0,
#  16.5,
#  16.0,
#  17.5,
#  16.0,
#  18.0,
#  16.5,
#  17.0,
#  16.0,
#  18.5,
#  15.5,
#  15.0,
#  19.5,
#  18.0,
#  15.5,
#  15.5,
#  15.0,
#  18.5,
#  15.5,
#  17.5,
#  19.0,
#  14.5,
#  17.5,
#  19.5,
#  19.5,
#  16.5,
#  20.0,
#  17.5,
#  20.0,
#  19.0,
#  19.0,
#  18.0,
#  17.5,
#  15.0,
#  18.0,
#  15.0,
#  16.0,
#  16.5,
#  15.0,
#  14.5,
#  17.0,
#  17.0,
#  20.0,
#  17.5,
#  16.0,
#  16.5,
#  19.5,
#  17.0,
#  16.5,
# ...

# %%
df2=df['Visibility (km)']>upper_limit
df2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13195    False
# 13196    False
# 13197    False
# 13198    False
# 13199    False
# Name: Visibility (km), Length: 13108, dtype: bool

# %%
df2=df.loc[df2]
df2
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 38            -9.0        49         1.5               58.0  partly cloudy
# 113           18.0        60        12.5               42.0       overcast
# 134           29.0        77         0.5               91.0         cloudy
# 300           48.0        79        12.0               88.0  partly cloudy
# 359            5.0        36        14.5               68.0         cloudy
# ...            ...       ...         ...                ...            ...
# 13018         -9.0        32         5.0               21.0  partly cloudy
# 13025         66.0       100         7.0              109.0          clear
# 13083         16.0        71         3.0               43.0       overcast
# 13163          5.0        67         9.5               71.0  partly cloudy
# 13178          0.0        50        11.5               82.0         cloudy
#
# ...

# %%
df.drop(df2.index,axis=0,inplace=True)
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 13195         10.0        74        14.5               71.0       overcast
# 13196         -1.0        76         3.5               23.0         cloudy
# 13197         30.0        77         5.5               28.0       overcast
# 13198          3.0        76        10.0               94.0       overcast
# 13199         -5.0        38         0.0               92.0       overcast
#
# ...

# %%
df.head(40)
# Out:
#     Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0          14.0        73         9.5               82.0  partly cloudy
# 1          39.0        96         8.5               71.0  partly cloudy
# 2          30.0        64         7.0               16.0          clear
# 3          38.0        83         1.5               82.0          clear
# 4          27.0        74        17.0               66.0       overcast
# 5          32.0        55         3.5               26.0       overcast
# 6          -2.0        97         8.0               86.0       overcast
# 7           3.0        85         6.0               96.0  partly cloudy
# 8           3.0        83         6.0               66.0       overcast
# 9          28.0        74         8.5              107.0          clear
# 10         35.0        45         6.0               86.0  partly cloudy
# 11         38.0        43         2.0               16.0          clear
# ...

# %%
df=df.reset_index(drop=True)
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 12720         10.0        74        14.5               71.0       overcast
# 12721         -1.0        76         3.5               23.0         cloudy
# 12722         30.0        77         5.5               28.0       overcast
# 12723          3.0        76        10.0               94.0       overcast
# 12724         -5.0        38         0.0               92.0       overcast
#
# ...

# %%
df.shape
# Out:
# (12725, 11)

# %% [markdown]
# # DATA TRANSFORMING

# %%
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 12720         10.0        74        14.5               71.0       overcast
# 12721         -1.0        76         3.5               23.0         cloudy
# 12722         30.0        77         5.5               28.0       overcast
# 12723          3.0        76        10.0               94.0       overcast
# 12724         -5.0        38         0.0               92.0       overcast
#
# ...

# %%
df.shape
# Out:
# (12725, 11)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.dtypes
# Out:
# Temperature             float64
# Humidity                  int64
# Wind Speed              float64
# Precipitation (%)       float64
# Cloud Cover              object
# Atmospheric Pressure    float64
# UV Index                  int64
# Season                   object
# Visibility (km)         float64
# Location                 object
# Weather Type             object
# dtype: object

# %%
for i in ['Cloud Cover','Season','Location','Weather Type']:
    df[i]=df[i]=le.fit_transform(df[i])
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0             14.0        73         9.5               82.0            3
# 1             39.0        96         8.5               71.0            3
# 2             30.0        64         7.0               16.0            0
# 3             38.0        83         1.5               82.0            0
# 4             27.0        74        17.0               66.0            2
# ...            ...       ...         ...                ...          ...
# 12720         10.0        74        14.5               71.0            2
# 12721         -1.0        76         3.5               23.0            1
# 12722         30.0        77         5.5               28.0            2
# 12723          3.0        76        10.0               94.0            2
# 12724         -5.0        38         0.0               92.0            2
#
#        Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# ...

# %%
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0             14.0        73         9.5               82.0            3
# 1             39.0        96         8.5               71.0            3
# 2             30.0        64         7.0               16.0            0
# 3             38.0        83         1.5               82.0            0
# 4             27.0        74        17.0               66.0            2
# ...            ...       ...         ...                ...          ...
# 12720         10.0        74        14.5               71.0            2
# 12721         -1.0        76         3.5               23.0            1
# 12722         30.0        77         5.5               28.0            2
# 12723          3.0        76        10.0               94.0            2
# 12724         -5.0        38         0.0               92.0            2
#
#        Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# ...

# %%
df.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0         14.0        73         9.5               82.0            3
# 1         39.0        96         8.5               71.0            3
# 2         30.0        64         7.0               16.0            0
# 3         38.0        83         1.5               82.0            0
# 4         27.0        74        17.0               66.0            2
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2       3              3.5         1
# 1               1011.43         7       1             10.0         1
# 2               1018.72         5       1              5.5         2
# 3               1026.25         7       1              1.0         0
# 4                990.67         1       3              2.5         2
#
#    Weather Type
# 0             1
# 1             0
# 2             3
# 3             3
# 4             1

# %%
df.dtypes
# Out:
# Temperature             float64
# Humidity                  int64
# Wind Speed              float64
# Precipitation (%)       float64
# Cloud Cover               int32
# Atmospheric Pressure    float64
# UV Index                  int64
# Season                    int32
# Visibility (km)         float64
# Location                  int32
# Weather Type              int32
# dtype: object

# %% [markdown]
# # Data Scaling

# %%
df.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0         14.0        73         9.5               82.0            3
# 1         39.0        96         8.5               71.0            3
# 2         30.0        64         7.0               16.0            0
# 3         38.0        83         1.5               82.0            0
# 4         27.0        74        17.0               66.0            2
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2       3              3.5         1
# 1               1011.43         7       1             10.0         1
# 2               1018.72         5       1              5.5         2
# 3               1026.25         7       1              1.0         0
# 4                990.67         1       3              2.5         2
#
#    Weather Type
# 0             1
# 1             0
# 2             3
# 3             3
# 4             1

# %%
df.dtypes
# Out:
# Temperature             float64
# Humidity                  int64
# Wind Speed              float64
# Precipitation (%)       float64
# Cloud Cover               int32
# Atmospheric Pressure    float64
# UV Index                  int64
# Season                    int32
# Visibility (km)         float64
# Location                  int32
# Weather Type              int32
# dtype: object

# %%
df.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind Speed', 'Precipitation (%)',
#        'Cloud Cover', 'Atmospheric Pressure', 'UV Index', 'Season',
#        'Visibility (km)', 'Location', 'Weather Type'],
#       dtype='object')

# %%
x = df.drop(['Weather Type'],axis=1)
y = df['Weather Type']

# %%
x.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0         14.0        73         9.5               82.0            3
# 1         39.0        96         8.5               71.0            3
# 2         30.0        64         7.0               16.0            0
# 3         38.0        83         1.5               82.0            0
# 4         27.0        74        17.0               66.0            2
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location
# 0               1010.82         2       3              3.5         1
# 1               1011.43         7       1             10.0         1
# 2               1018.72         5       1              5.5         2
# 3               1026.25         7       1              1.0         0
# 4                990.67         1       3              2.5         2

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    3
# 3    3
# 4    1
# Name: Weather Type, dtype: int32

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
x.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind Speed', 'Precipitation (%)',
#        'Cloud Cover', 'Atmospheric Pressure', 'UV Index', 'Season',
#        'Visibility (km)', 'Location'],
#       dtype='object')

# %%
a=minmax.fit_transform(x)
a
# Out:
# array([[0.40625   , 0.59550562, 0.19587629, ..., 1.        , 0.25      ,
#         0.5       ],
#        [0.66666667, 0.85393258, 0.17525773, ..., 0.33333333, 0.71428571,
#         0.5       ],
#        [0.57291667, 0.49438202, 0.1443299 , ..., 0.33333333, 0.39285714,
#         1.        ],
#        ...,
#        [0.57291667, 0.64044944, 0.11340206, ..., 0.        , 0.64285714,
#         0.        ],
#        [0.29166667, 0.62921348, 0.20618557, ..., 1.        , 0.14285714,
#         0.5       ],
#        [0.20833333, 0.20224719, 0.        , ..., 0.        , 0.71428571,
#         1.        ]])

# %%
a= pd.DataFrame(a,columns=['Temperature', 'Humidity', 'Wind Speed', 'Precipitation (%)',
       'Cloud Cover', 'Atmospheric Pressure', 'UV Index', 'Season',
       'Visibility (km)', 'Location'])
a
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0         0.406250  0.595506    0.195876           0.752294     1.000000
# 1         0.666667  0.853933    0.175258           0.651376     1.000000
# 2         0.572917  0.494382    0.144330           0.146789     0.000000
# 3         0.656250  0.707865    0.030928           0.752294     0.000000
# 4         0.541667  0.606742    0.350515           0.605505     0.666667
# ...            ...       ...         ...                ...          ...
# 12720     0.364583  0.606742    0.298969           0.651376     0.666667
# 12721     0.250000  0.629213    0.072165           0.211009     0.333333
# 12722     0.572917  0.640449    0.113402           0.256881     0.666667
# 12723     0.291667  0.629213    0.206186           0.862385     0.666667
# 12724     0.208333  0.202247    0.000000           0.844037     0.666667
#
#        Atmospheric Pressure  UV Index    Season  Visibility (km)  Location
# ...

# %%
output=pd.concat([a,y],axis=1)
output
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0         0.406250  0.595506    0.195876           0.752294     1.000000
# 1         0.666667  0.853933    0.175258           0.651376     1.000000
# 2         0.572917  0.494382    0.144330           0.146789     0.000000
# 3         0.656250  0.707865    0.030928           0.752294     0.000000
# 4         0.541667  0.606742    0.350515           0.605505     0.666667
# ...            ...       ...         ...                ...          ...
# 12720     0.364583  0.606742    0.298969           0.651376     0.666667
# 12721     0.250000  0.629213    0.072165           0.211009     0.333333
# 12722     0.572917  0.640449    0.113402           0.256881     0.666667
# 12723     0.291667  0.629213    0.206186           0.862385     0.666667
# 12724     0.208333  0.202247    0.000000           0.844037     0.666667
#
#        Atmospheric Pressure  UV Index    Season  Visibility (km)  Location  \
# ...

# %%
output.describe()
# Out:
#         Temperature      Humidity    Wind Speed  Precipitation (%)  \
# count  12725.000000  12725.000000  12725.000000       12725.000000
# mean       0.456591      0.552041      0.203470           0.489189
# std        0.171078      0.224389      0.142893           0.293716
# min        0.000000      0.000000      0.000000           0.000000
# 25%        0.302083      0.426966      0.103093           0.174312
# 50%        0.479167      0.561798      0.185567           0.532110
# 75%        0.572917      0.719101      0.278351           0.752294
# max        1.000000      1.000000      1.000000           1.000000
#
#         Cloud Cover  Atmospheric Pressure      UV Index        Season  \
# count  12725.000000          12725.000000  12725.000000  12725.000000
# mean       0.665593              0.515232      0.277508      0.621585
# std        0.337329              0.081220      0.270000      0.387826
# min        0.000000              0.000000      0.000000      0.000000
# ...

# %% [markdown]
# # DATA VISUALISING

# %%
sns.distplot(output['Temperature'],color='b')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_21528\1856006018.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(output['Temperature'],color='b')
# <Axes: xlabel='Temperature', ylabel='Density'>

# %%
# Assuming 'output' is your DataFrame
sns.countplot(data=output, x='Weather Type', color='y')
plt.title('Frequency of Weather Types')
plt.xlabel('Weather Type')
plt.ylabel('Count')
plt.show()

# %%
output['Weather Type'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.lineplot(data=output, x='Visibility (km)', y='Temperature', hue='Season')
# Out:
# <Axes: xlabel='Visibility (km)', ylabel='Temperature'>

# %% [markdown]
# # Conclusion
# The weather dataset was analyzed and cleaned to address missing values, outliers, and inconsistencies. Features were transformed and scaled to improve model performance. Visualizations revealed key trends and relationships, such as the impact of Temperature, Humidity, and Season on Weather Type. The dataset is now ready for classification modeling to predict weather conditions effectively.
