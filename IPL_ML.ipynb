# %% [markdown]
# # IPL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Asus\Downloads\ipl.csv')

# %% [markdown]
# # DATA ANALYSING

# %%
df
# Out:
#        mid  Unnamed: 1                                      venue  \
# 0        1         NaN                      M Chinnaswamy Stadium
# 1        1         NaN                      M Chinnaswamy Stadium
# 2        1         NaN                      M Chinnaswamy Stadium
# 3        1         NaN                      M Chinnaswamy Stadium
# 4        1         NaN                      M Chinnaswamy Stadium
# ...    ...         ...                                        ...
# 76009  617         NaN  Rajiv Gandhi International Stadium, Uppal
# 76010  617         NaN  Rajiv Gandhi International Stadium, Uppal
# 76011  617         NaN  Rajiv Gandhi International Stadium, Uppal
# 76012  617         NaN  Rajiv Gandhi International Stadium, Uppal
# 76013  617         NaN  Rajiv Gandhi International Stadium, Uppal
#
#                     bat_team                    bowl_team      batsman  \
# 0      Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# ...

# %%
df.drop("Unnamed: 1",axis=1,inplace=True)

# %%
df.head()
# Out:
#    mid                  venue               bat_team  \
# 0    1  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1    1  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2    1  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3    1  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4    1  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                      bowl_team      batsman   bowler  runs  wickets  overs  \
# 0  Royal Challengers Bangalore   SC Ganguly  P Kumar     1        0    0.1
# 1  Royal Challengers Bangalore  BB McCullum  P Kumar     1        0    0.2
# 2  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.2
# 3  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.3
# 4  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.4
#
#    runs_last_5  wickets_last_5  striker  non-striker  total
# 0            1               0        0            0    222
# 1            1               0        0            0    222
# ...

# %%
df.tail()
# Out:
#        mid                                      venue        bat_team  \
# 76009  617  Rajiv Gandhi International Stadium, Uppal  Mumbai Indians
# 76010  617  Rajiv Gandhi International Stadium, Uppal  Mumbai Indians
# 76011  617  Rajiv Gandhi International Stadium, Uppal  Mumbai Indians
# 76012  617  Rajiv Gandhi International Stadium, Uppal  Mumbai Indians
# 76013  617  Rajiv Gandhi International Stadium, Uppal  Mumbai Indians
#
#                     bowl_team     batsman        bowler  runs  wickets  overs  \
# 76009  Rising Pune Supergiant   KH Pandya  DT Christian   121        7   19.2
# 76010  Rising Pune Supergiant   KH Pandya  DT Christian   127        7   19.3
# 76011  Rising Pune Supergiant   KH Pandya  DT Christian   128        7   19.4
# 76012  Rising Pune Supergiant  MG Johnson  DT Christian   129        7   19.5
# 76013  Rising Pune Supergiant   KH Pandya  DT Christian   129        8   19.6
#
#        runs_last_5  wickets_last_5  striker  non-striker  total
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76014 entries, 0 to 76013
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mid             76014 non-null  int64
#  1   venue           76014 non-null  object
#  2   bat_team        76014 non-null  object
#  3   bowl_team       76014 non-null  object
#  4   batsman         76014 non-null  object
#  5   bowler          76014 non-null  object
#  6   runs            76014 non-null  int64
#  7   wickets         76014 non-null  int64
#  8   overs           76014 non-null  float64
#  9   runs_last_5     76014 non-null  int64
#  10  wickets_last_5  76014 non-null  int64
#  11  striker         76014 non-null  int64
#  12  non-striker     76014 non-null  int64
#  13  total           76014 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 8.1+ MB

# %%
df.columns
# Out:
# Index(['mid', 'venue', 'bat_team', 'bowl_team', 'batsman', 'bowler', 'runs',
#        'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
#        'non-striker', 'total'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# mid               0
# venue             0
# bat_team          0
# bowl_team         0
# batsman           0
# bowler            0
# runs              0
# wickets           0
# overs             0
# runs_last_5       0
# wickets_last_5    0
# striker           0
# non-striker       0
# total             0
# dtype: int64

# %%
df.dtypes
# Out:
# mid                 int64
# venue              object
# bat_team           object
# bowl_team          object
# batsman            object
# bowler             object
# runs                int64
# wickets             int64
# overs             float64
# runs_last_5         int64
# wickets_last_5      int64
# striker             int64
# non-striker         int64
# total               int64
# dtype: object

# %%
graph=df.select_dtypes(include=['float'])
graph
# Out:
#        overs
# 0        0.1
# 1        0.2
# 2        0.2
# 3        0.3
# 4        0.4
# ...      ...
# 76009   19.2
# 76010   19.3
# 76011   19.4
# 76012   19.5
# 76013   19.6
#
# [76014 rows x 1 columns]

# %% [markdown]
# # DATA CLEANING

# %%
plt.boxplot(df['runs_last_5'])
plt.title('runs_last_5')
# Out:
# Text(0.5, 1.0, 'runs_last_5')

# %%
plt.boxplot(df['wickets_last_5'])
plt.title('wickets_last_5')
# Out:
# Text(0.5, 1.0, 'wickets_last_5')

# %%
Q1=np.percentile(df['runs_last_5'],25,interpolation='midpoint')
Q2=np.percentile(df['runs_last_5'],50,interpolation='midpoint')
Q3=np.percentile(df['runs_last_5'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 24.0
# 34.0
# 43.0

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 19.0

# %%
upper_limit=Q3+1.5*IQR
lower_limit=Q1-1.5*IQR
print(upper_limit)
print(lower_limit)
# Out:
# 71.5
# -4.5

# %%
outlier=[]
for x in df['runs_last_5']:
  if((x>upper_limit) or (x<lower_limit)):
    outlier.append(x)
outlier
# Out:
# [72,
#  74,
#  79,
#  81,
#  81,
#  83,
#  79,
#  72,
#  76,
#  76,
#  77,
#  80,
#  86,
#  86,
#  80,
#  76,
#  76,
#  77,
#  77,
#  75,
#  76,
#  76,
#  78,
#  74,
#  77,
#  80,
#  85,
#  72,
#  75,
#  76,
#  76,
#  72,
#  73,
#  72,
#  72,
#  72,
#  72,
#  72,
#  72,
#  78,
#  78,
#  78,
#  83,
#  83,
#  88,
#  87,
#  93,
#  94,
#  93,
#  87,
#  87,
#  86,
#  89,
#  89,
#  92,
#  87,
#  88,
#  91,
#  91,
#  93,
#  88,
#  88,
#  85,
#  79,
#  80,
#  80,
#  79,
#  73,
#  79,
#  73,
#  72,
#  72,
#  74,
#  73,
#  73,
#  79,
#  79,
#  79,
#  79,
#  85,
#  79,
#  79,
#  79,
#  80,
#  80,
#  77,
#  74,
#  74,
#  72,
#  72,
#  76,
#  74,
#  75,
#  75,
#  74,
#  74,
#  72,
#  74,
#  73,
#  77,
#  77,
#  73,
#  72,
#  76,
#  78,
#  80,
#  74,
#  72,
#  72,
#  72,
#  73,
#  79,
#  73,
#  73,
#  72,
#  73,
#  73,
#  73,
#  76,
#  76,
#  73,
#  73,
#  73,
#  74,
#  77,
#  76,
#  74,
#  73,
#  72,
#  74,
#  77,
#  73,
#  73,
#  79,
#  82,
#  83,
#  87,
#  87,
#  93,
#  91,
#  92,
#  89,
# ...

# %%
Q1=np.percentile(df['wickets_last_5'],25,interpolation='midpoint')
Q2=np.percentile(df['wickets_last_5'],50,interpolation='midpoint')
Q3=np.percentile(df['wickets_last_5'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 0.0
# 1.0
# 2.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 2.0

# %%
upper_limit=Q3+1.5*IQR
lower_limit=Q1-1.5*IQR
print(upper_limit)
print(lower_limit)
# Out:
# 5.0
# -3.0

# %%
outlier=[]
for i in df['wickets_last_5']:
    if((i>upper_limit)or(i<lower_limit)):
        outlier.append(i)
outlier
# Out:
# [6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  7,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  7,
#  7,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  7,
#  7,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6,
#  6]

# %%
a1=((df["wickets_last_5"]>upper_limit)|(df["wickets_last_5"]<lower_limit))
a1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 76009    False
# 76010    False
# 76011    False
# 76012    False
# 76013    False
# Name: wickets_last_5, Length: 76014, dtype: bool

# %%
a1=df.loc[a1]
a1
# Out:
#        mid                                       venue  \
# 1231    10  Punjab Cricket Association Stadium, Mohali
# 2600    21   Rajiv Gandhi International Stadium, Uppal
# 2602    21   Rajiv Gandhi International Stadium, Uppal
# 3088    25                       M Chinnaswamy Stadium
# 7965    65                                   Kingsmead
# ...    ...                                         ...
# 70987  576                       M Chinnaswamy Stadium
# 75282  611                                  Green Park
# 75283  611                                  Green Park
# 75284  611                                  Green Park
# 75285  611                                  Green Park
#
#                           bat_team                    bowl_team     batsman  \
# 1231               Kings XI Punjab               Mumbai Indians       B Lee
# 2600               Deccan Chargers  Royal Challengers Bangalore    AS Yadav
# ...

# %%
df.drop(a1.index,axis=0,inplace=True)
df
# Out:
#        mid                                      venue               bat_team  \
# 0        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# 1        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# 2        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# 3        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# 4        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# ...    ...                                        ...                    ...
# 76009  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76010  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76011  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76012  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76013  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
#
# ...

# %%
df=df.reset_index(drop=True)

# %%
df.shape
# Out:
# (75944, 14)

# %% [markdown]
# # DATA TRANSFORMING

# %%
df
# Out:
#        mid                                      venue               bat_team  \
# 0        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# 1        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# 2        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# 3        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# 4        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# ...    ...                                        ...                    ...
# 75939  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 75940  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 75941  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 75942  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 75943  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
#
# ...

# %%
df.dtypes
# Out:
# mid                 int64
# venue              object
# bat_team           object
# bowl_team          object
# batsman            object
# bowler             object
# runs                int64
# wickets             int64
# overs             float64
# runs_last_5         int64
# wickets_last_5      int64
# striker             int64
# non-striker         int64
# total               int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
enc=df.select_dtypes(include=['object'])
enc
# Out:
#                                            venue               bat_team  \
# 0                          M Chinnaswamy Stadium  Kolkata Knight Riders
# 1                          M Chinnaswamy Stadium  Kolkata Knight Riders
# 2                          M Chinnaswamy Stadium  Kolkata Knight Riders
# 3                          M Chinnaswamy Stadium  Kolkata Knight Riders
# 4                          M Chinnaswamy Stadium  Kolkata Knight Riders
# ...                                          ...                    ...
# 75939  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 75940  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 75941  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 75942  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 75943  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
#
#                          bowl_team      batsman        bowler
# ...

# %%
for i in ['venue','bat_team','bowl_team','batsman','bowler']:
    df[i]=le.fit_transform(df[i])
df
# Out:
#        mid  venue  bat_team  bowl_team  batsman  bowler  runs  wickets  overs  \
# 0        1     14         6         12      327     201     1        0    0.1
# 1        1     14         6         12       61     201     1        0    0.2
# 2        1     14         6         12       61     201     2        0    0.2
# 3        1     14         6         12       61     201     2        0    0.3
# 4        1     14         6         12       61     201     2        0    0.4
# ...    ...    ...       ...        ...      ...     ...   ...      ...    ...
# 75939  617     23         7         10      172      96   121        7   19.2
# 75940  617     23         7         10      172      96   127        7   19.3
# 75941  617     23         7         10      172      96   128        7   19.4
# 75942  617     23         7         10      215      96   129        7   19.5
# 75943  617     23         7         10      172      96   129        8   19.6
#
# ...

# %%
df.head()
# Out:
#    mid  venue  bat_team  bowl_team  batsman  bowler  runs  wickets  overs  \
# 0    1     14         6         12      327     201     1        0    0.1
# 1    1     14         6         12       61     201     1        0    0.2
# 2    1     14         6         12       61     201     2        0    0.2
# 3    1     14         6         12       61     201     2        0    0.3
# 4    1     14         6         12       61     201     2        0    0.4
#
#    runs_last_5  wickets_last_5  striker  non-striker  total
# 0            1               0        0            0    222
# 1            1               0        0            0    222
# 2            2               0        0            0    222
# 3            2               0        0            0    222
# 4            2               0        0            0    222

# %%
df.dtypes
# Out:
# mid                 int64
# venue               int32
# bat_team            int32
# bowl_team           int32
# batsman             int32
# bowler              int32
# runs                int64
# wickets             int64
# overs             float64
# runs_last_5         int64
# wickets_last_5      int64
# striker             int64
# non-striker         int64
# total               int64
# dtype: object

# %% [markdown]
# # DATA SCALING

# %%
df.head()
# Out:
#    mid  venue  bat_team  bowl_team  batsman  bowler  runs  wickets  overs  \
# 0    1     14         6         12      327     201     1        0    0.1
# 1    1     14         6         12       61     201     1        0    0.2
# 2    1     14         6         12       61     201     2        0    0.2
# 3    1     14         6         12       61     201     2        0    0.3
# 4    1     14         6         12       61     201     2        0    0.4
#
#    runs_last_5  wickets_last_5  striker  non-striker  total
# 0            1               0        0            0    222
# 1            1               0        0            0    222
# 2            2               0        0            0    222
# 3            2               0        0            0    222
# 4            2               0        0            0    222

# %%
df.dtypes
# Out:
# mid                 int64
# venue               int32
# bat_team            int32
# bowl_team           int32
# batsman             int32
# bowler              int32
# runs                int64
# wickets             int64
# overs             float64
# runs_last_5         int64
# wickets_last_5      int64
# striker             int64
# non-striker         int64
# total               int64
# dtype: object

# %%
df.columns
# Out:
# Index(['mid', 'venue', 'bat_team', 'bowl_team', 'batsman', 'bowler', 'runs',
#        'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
#        'non-striker', 'total'],
#       dtype='object')

# %%
x = df.drop('total',axis=1)
y = df['total']

# %%
x.head()
# Out:
#    mid  venue  bat_team  bowl_team  batsman  bowler  runs  wickets  overs  \
# 0    1     14         6         12      327     201     1        0    0.1
# 1    1     14         6         12       61     201     1        0    0.2
# 2    1     14         6         12       61     201     2        0    0.2
# 3    1     14         6         12       61     201     2        0    0.3
# 4    1     14         6         12       61     201     2        0    0.4
#
#    runs_last_5  wickets_last_5  striker  non-striker
# 0            1               0        0            0
# 1            1               0        0            0
# 2            2               0        0            0
# 3            2               0        0            0
# 4            2               0        0            0

# %%
y.head()
# Out:
# 0    222
# 1    222
# 2    222
# 3    222
# 4    222
# Name: total, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax=MinMaxScaler()

# %%
x=minmax.fit_transform(x)

# %%
x
# Out:
# array([[0.        , 0.41176471, 0.46153846, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.41176471, 0.46153846, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.41176471, 0.46153846, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [1.        , 0.67647059, 0.53846154, ..., 0.        , 0.26857143,
#         0.11009174],
#        [1.        , 0.67647059, 0.53846154, ..., 0.        , 0.26857143,
#         0.11926606],
#        [1.        , 0.67647059, 0.53846154, ..., 0.2       , 0.26857143,
#         0.11926606]])

# %%
a=pd.DataFrame(x,columns=['mid', 'venue', 'bat_team', 'bowl_team', 'batsman', 'bowler', 'runs',
       'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
       'non-striker'])

# %%
a
# Out:
#        mid     venue  bat_team  bowl_team   batsman    bowler      runs  \
# 0      0.0  0.411765  0.461538   0.923077  0.799511  0.612805  0.003802
# 1      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.003802
# 2      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# 3      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# 4      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# ...    ...       ...       ...        ...       ...       ...       ...
# 75939  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.460076
# 75940  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.482890
# 75941  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.486692
# 75942  1.0  0.676471  0.538462   0.769231  0.525672  0.292683  0.490494
# 75943  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.490494
#
#        wickets     overs  runs_last_5  wickets_last_5   striker  non-striker
# ...

# %%
output=pd.concat([a,y],axis=1)
output
# Out:
#        mid     venue  bat_team  bowl_team   batsman    bowler      runs  \
# 0      0.0  0.411765  0.461538   0.923077  0.799511  0.612805  0.003802
# 1      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.003802
# 2      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# 3      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# 4      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# ...    ...       ...       ...        ...       ...       ...       ...
# 75939  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.460076
# 75940  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.482890
# 75941  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.486692
# 75942  1.0  0.676471  0.538462   0.769231  0.525672  0.292683  0.490494
# 75943  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.490494
#
#        wickets     overs  runs_last_5  wickets_last_5   striker  non-striker  \
# ...

# %%
output.describe()
# Out:
#                 mid         venue      bat_team     bowl_team       batsman  \
# count  75944.000000  75944.000000  75944.000000  75944.000000  75944.000000
# mean       0.499374      0.515556      0.456312      0.467035      0.513741
# std        0.289259      0.282100      0.317950      0.304951      0.284018
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.248377      0.235294      0.153846      0.153846      0.268949
# 50%        0.498377      0.441176      0.461538      0.461538      0.511002
# 75%        0.750000      0.735294      0.692308      0.692308      0.760391
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#              bowler          runs       wickets         overs   runs_last_5  \
# count  75944.000000  75944.000000  75944.000000  75944.000000  75944.000000
# mean       0.517723      0.284513      0.240996      0.498708      0.293956
# ...

# %% [markdown]
# # DATA VISUALISING

# %%
sns.jointplot(x='batsman', y='bowler',color='b',data=output)

# %%
sns.distplot(output['mid'],color='g')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_37616\1340800288.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(output['mid'],color='g')
# <Axes: xlabel='mid', ylabel='Density'>

# %%
sns.kdeplot(output['wickets'],color='r')
# Out:
# <Axes: xlabel='wickets', ylabel='Density'>

# %%
output.corr()
# Out:
#                      mid     venue  bat_team  bowl_team   batsman    bowler  \
# mid             1.000000  0.015444  0.238611   0.116112 -0.046603 -0.031670
# venue           0.015444  1.000000  0.103799   0.071968 -0.027080 -0.033665
# bat_team        0.238611  0.103799  1.000000  -0.101542 -0.012800 -0.009804
# bowl_team       0.116112  0.071968 -0.101542   1.000000 -0.031155 -0.010804
# batsman        -0.046603 -0.027080 -0.012800  -0.031155  1.000000  0.012008
# bowler         -0.031670 -0.033665 -0.009804  -0.010804  0.012008  1.000000
# runs            0.026358 -0.017536 -0.003003  -0.006614 -0.024185 -0.006981
# wickets        -0.055573  0.001593 -0.028742  -0.007156 -0.026597  0.003523
# overs           0.002409  0.001332  0.001316  -0.003102 -0.030368 -0.001836
# runs_last_5     0.045329 -0.021233  0.004407  -0.010833 -0.005875  0.001623
# wickets_last_5 -0.032576 -0.000927 -0.017159   0.004254 -0.006378  0.007676
# ...

# %%
sns.heatmap(output.corr())
# Out:
# <Axes: >

# %% [markdown]
# # ML

# %%
# lin regg

# %%
x=output.drop('total',axis=1)
y=output['total']

# %%
x
# Out:
#        mid     venue  bat_team  bowl_team   batsman    bowler      runs  \
# 0      0.0  0.411765  0.461538   0.923077  0.799511  0.612805  0.003802
# 1      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.003802
# 2      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# 3      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# 4      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# ...    ...       ...       ...        ...       ...       ...       ...
# 75939  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.460076
# 75940  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.482890
# 75941  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.486692
# 75942  1.0  0.676471  0.538462   0.769231  0.525672  0.292683  0.490494
# 75943  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.490494
#
#        wickets     overs  runs_last_5  wickets_last_5   striker  non-striker
# ...

# %%
y
# Out:
# 0        222
# 1        222
# 2        222
# 3        222
# 4        222
#         ...
# 75939    129
# 75940    129
# 75941    129
# 75942    129
# 75943    129
# Name: total, Length: 75944, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
model=lr.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
print(y_pred)
# Out:
# [163.7338962  140.39642518 138.11599276 ... 149.59292375 164.97208545
#  165.27970563]

# %%
print(y_test)
# Out:
# 18713    138
# 47399    130
# 22194    148
# 11248    173
# 15851    183
#         ...
# 24237    142
# 29464    205
# 20167    132
# 63735    185
# 50133    152
# Name: total, Length: 18986, dtype: int64

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 408.2395706048171

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.5152829295757341

# %%
x_train.head()
# Out:
#             mid     venue  bat_team  bowl_team   batsman    bowler      runs  \
# 10415  0.136364  0.941176  0.923077   0.692308  0.936430  0.512195  0.273764
# 64962  0.855519  0.235294  0.153846   0.461538  0.723716  0.070122  0.707224
# 67502  0.889610  0.205882  0.461538   0.923077  0.537897  0.853659  0.376426
# 10999  0.144481  0.529412  0.461538   0.153846  0.995110  0.920732  0.159696
# 74809  0.985390  0.264706  0.230769   0.153846  0.075795  0.637195  0.384030
#
#        wickets     overs  runs_last_5  wickets_last_5   striker  non-striker
# 10415      0.5  0.693878     0.238938             0.2  0.085714     0.100917
# 64962      0.8  1.000000     0.584071             1.0  0.022857     0.000000
# 67502      0.2  0.576531     0.283186             0.2  0.240000     0.009174
# 10999      0.3  0.331633     0.292035             0.0  0.120000     0.100917
# 74809      0.3  0.581633     0.353982             0.0  0.148571     0.192661

# %%
y_train.head()
# Out:
# 10415    105
# 64962    186
# 67502    183
# 10999    123
# 74809    195
# Name: total, dtype: int64

# %% [markdown]
# # KNN MODEL

# %%
x=output.drop('total',axis=1)
y=output['total']
print(y)
print(x)
# Out:
# 0        222
# 1        222
# 2        222
# 3        222
# 4        222
#         ...
# 75939    129
# 75940    129
# 75941    129
# 75942    129
# 75943    129
# Name: total, Length: 75944, dtype: int64
#        mid     venue  bat_team  bowl_team   batsman    bowler      runs  \
# 0      0.0  0.411765  0.461538   0.923077  0.799511  0.612805  0.003802
# 1      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.003802
# 2      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# 3      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# 4      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# ...    ...       ...       ...        ...       ...       ...       ...
# 75939  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.460076
# 75940  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.482890
# 75941  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.486692
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.neighbors import KNeighborsRegressor  
from sklearn.metrics import mean_squared_error,r2_score
metric_k= []
neighbors = np.arange(2, 15)

for k in neighbors:
    knn=KNeighborsRegressor(n_neighbors=k)
    model2=knn.fit(x_train,y_train)
    y_pred_knn=model2.predict(x_test)
    accuracy=r2_score(y_test,y_pred_knn)
    metric_k.append(accuracy)

# %%
metric_k
# Out:
# [0.9526088388879868,
#  0.9379213096285282,
#  0.9200607431656638,
#  0.9023346228805722,
#  0.8842106846369642,
#  0.8670327397085126,
#  0.8515548384061776,
#  0.8366246672531485,
#  0.8234792801621877,
#  0.811739145875088,
#  0.8000133291306544,
#  0.7882039146218116,
#  0.7776754733749092]

# %%
plt.plot(neighbors,metric_k,'o--',color='r')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
plt.grid()

# %%
knn=KNeighborsRegressor(n_neighbors=2)
model_knn=knn.fit(x_train,y_train)
y_pred_knn=model_knn.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print(mean_squared_error(y_test,y_pred_knn))
# Out:
# 39.913897082060465

# %%
print(r2_score(y_test,y_pred_knn))
# Out:
# 0.9526088388879868

# %% [markdown]
# # SVM

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.svm import SVR

# %%
svm_reg=SVR(kernel='rbf')

# %%
svm_model=svm_reg.fit(x_train,y_train)

# %%
y_pred_svm=svm_model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print(mean_squared_error(y_test,y_pred_svm))
# Out:
# 388.7092856376972

# %%
print(r2_score(y_test,y_pred_svm))
# Out:
# 0.5384719176000659

# %%
x.head()
# Out:
#    mid     venue  bat_team  bowl_team   batsman    bowler      runs  wickets  \
# 0  0.0  0.411765  0.461538   0.923077  0.799511  0.612805  0.003802      0.0
# 1  0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.003802      0.0
# 2  0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605      0.0
# 3  0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605      0.0
# 4  0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605      0.0
#
#       overs  runs_last_5  wickets_last_5  striker  non-striker
# 0  0.005102     0.008850             0.0      0.0          0.0
# 1  0.010204     0.008850             0.0      0.0          0.0
# 2  0.010204     0.017699             0.0      0.0          0.0
# 3  0.015306     0.017699             0.0      0.0          0.0
# 4  0.020408     0.017699             0.0      0.0          0.0

# %%
y.head()
# Out:
# 0    222
# 1    222
# 2    222
# 3    222
# 4    222
# Name: total, dtype: int64

# %% [markdown]
# # D T

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
print(y)
print(x)
# Out:
# 0        222
# 1        222
# 2        222
# 3        222
# 4        222
#         ...
# 75939    129
# 75940    129
# 75941    129
# 75942    129
# 75943    129
# Name: total, Length: 75944, dtype: int64
#        mid     venue  bat_team  bowl_team   batsman    bowler      runs  \
# 0      0.0  0.411765  0.461538   0.923077  0.799511  0.612805  0.003802
# 1      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.003802
# 2      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# 3      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# 4      0.0  0.411765  0.461538   0.923077  0.149144  0.612805  0.007605
# ...    ...       ...       ...        ...       ...       ...       ...
# 75939  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.460076
# 75940  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.482890
# 75941  1.0  0.676471  0.538462   0.769231  0.420538  0.292683  0.486692
# ...

# %%
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#             mid     venue  bat_team  bowl_team   batsman    bowler      runs  \
# 10415  0.136364  0.941176  0.923077   0.692308  0.936430  0.512195  0.273764
# 64962  0.855519  0.235294  0.153846   0.461538  0.723716  0.070122  0.707224
# 67502  0.889610  0.205882  0.461538   0.923077  0.537897  0.853659  0.376426
# 10999  0.144481  0.529412  0.461538   0.153846  0.995110  0.920732  0.159696
# 74809  0.985390  0.264706  0.230769   0.153846  0.075795  0.637195  0.384030
# ...         ...       ...       ...        ...       ...       ...       ...
# 37194  0.488636  1.000000  0.461538   0.538462  0.298289  0.435976  0.167300
# 6265   0.082792  0.764706  0.538462   0.692308  0.845966  0.853659  0.060837
# 54886  0.722403  0.029412  0.538462   0.000000  0.709046  0.021341  0.486692
# 860    0.011364  0.441176  0.000000   0.538462  0.630807  0.838415  0.019011
# 15795  0.206169  0.411765  0.923077   0.000000  0.743276  0.368902  0.452471
#
# ...

# %%
from sklearn.tree import DecisionTreeRegressor #DecisionTreeClassifier

# %%
dt_reg= DecisionTreeRegressor(random_state=42)

# %%
dt_model=dt_reg.fit(x_train,y_train)

# %%
y_pred_dt=dt_model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print(mean_squared_error(y_test,y_pred_dt))
# Out:
# 61.39260507742547

# %%
print(r2_score(y_test,y_pred_dt))
# Out:
# 0.9271064202944455

# %%
# ACCURACY OF D T MODEL IS 92%

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_reg= RandomForestRegressor(random_state=42)

# %%
rf_model=rf_reg.fit(x_train,y_train)

# %%
y_pred_rf=rf_model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print(mean_squared_error(y_test,y_pred_rf))
# Out:
# 22.396719509111975

# %%
print(r2_score(y_test,y_pred_rf))
# Out:
# 0.9734075943410209

# %%
# Accuracy of Random Forest model is 97%

# %%
x_train.head(8)
# Out:
#             mid     venue  bat_team  bowl_team   batsman    bowler      runs  \
# 10415  0.136364  0.941176  0.923077   0.692308  0.936430  0.512195  0.273764
# 64962  0.855519  0.235294  0.153846   0.461538  0.723716  0.070122  0.707224
# 67502  0.889610  0.205882  0.461538   0.923077  0.537897  0.853659  0.376426
# 10999  0.144481  0.529412  0.461538   0.153846  0.995110  0.920732  0.159696
# 74809  0.985390  0.264706  0.230769   0.153846  0.075795  0.637195  0.384030
# 69004  0.909091  0.470588  0.538462   0.769231  0.420538  0.664634  0.406844
# 18948  0.246753  0.411765  0.461538   0.923077  0.334963  0.692073  0.589354
# 54930  0.724026  1.000000  0.307692   0.000000  0.498778  0.557927  0.057034
#
#        wickets     overs  runs_last_5  wickets_last_5   striker  non-striker
# 10415      0.5  0.693878     0.238938             0.2  0.085714     0.100917
# 64962      0.8  1.000000     0.584071             1.0  0.022857     0.000000
# ...

# %%
y_train.head(8)
# Out:
# 10415    105
# 64962    186
# 67502    183
# 10999    123
# 74809    195
# 69004    184
# 18948    160
# 54930    226
# Name: total, dtype: int64

# %%
rf_model.predict([[0.136364,	0.941176,	0.923077,	0.692308,	0.936430,	0.512195,	0.273764,	0.5	,0.693878	,0.238938,	0.2,	0.085714,	0.100917]])
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([105.05])

# %%
rf_model.predict([[0.855519,	0.235294,	0.153846,	0.461538,	0.723716,	0.070122,	0.707224,	0.8	,1.000000	,0.584071,	1.0	,0.022857,	0.000000]])
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([186.22])

# %%
rf_model.predict([[0.724026,	1.000000,	0.307692,	0.000000,	0.498778,	0.557927,	0.057034,	0.0,	0.127551,	0.132743,	0.0,	0.045714	,0.055046]])
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([225.12])

# %% [markdown]
# # Ada Boost

# %%
from sklearn.ensemble import AdaBoostRegressor
model_ada= AdaBoostRegressor()
model_ada.fit(x_train,y_train)
pred_ada= model_ada.predict(x_test)
pred_ada
# Out:
# array([156.80790377, 149.78134834, 142.42462286, ..., 142.42462286,
#        162.91370691, 148.78638338])

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print(mean_squared_error(y_test,pred_ada))
# Out:
# 511.7128337536279

# %%
print(r2_score(y_test,pred_ada))
# Out:
# 0.39242551791810265

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
model_gra= GradientBoostingRegressor()
model_gra.fit(x_train,y_train)
pred_gra = model_gra.predict(x_test)
pred_gra
# Out:
# array([163.34795561, 142.93607981, 130.35263016, ..., 143.74110479,
#        168.96520209, 154.29833869])

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print(mean_squared_error(y_test,pred_gra))
# Out:
# 345.78553072097145

# %%
print(r2_score(y_test,pred_gra))
# Out:
# 0.5894367878208042

# %% [markdown]
# # XG Boost

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBRegressor
model_xgb = XGBRegressor()
model_xgb.fit(x_train,y_train)
pred_xgb = model_xgb.predict(x_test)
pred_xgb
# Out:
# array([147.88129, 132.93166, 142.68877, ..., 137.0599 , 177.5854 ,
#        160.41559], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print(mean_squared_error(y_test,pred_xgb))
# Out:
# 47.43353323371995

# %%
print(r2_score(y_test,pred_xgb))
# Out:
# 0.9436805128056112

# %% [markdown]
# # Performance Analysis

# %%
lg_score  =51 # Linear Regression
knn_score =95 # K nearest
svm_scodre=53 # support vector
dt_score  =92 # decision tree
rf_score  =97 # random forest
xgb_score =93 # xg boost

# %%
algorithms = ['Lin Reg','KNN' ,'SVM','DT','Random Forest','XGB']
scores = [lg_score,knn_score,svm_scodre,dt_score,rf_score,xgb_score]

# Plotting the bar graph 
plt.figure(figsize=(10, 5))
plt.bar(algorithms, scores, color=['yellow', 'orange', 'green', 'pink', 'red','cyan'])
plt.xlabel("Algorithms")
plt.ylabel("R2score")
plt.title("Performance Analysis of Different Regression Algorithms")
plt.ylim(0, max(scores) + 1) 
plt.grid(axis='y',alpha=0.5)
plt.show()

# %% [markdown]
# # Conclusion

# %% [raw]
# The dataset was analyzed using multiple machine learning models to predict the target variable. The Linear Regression model achieved an accuracy of 51%, while the Support Vector Machine (SVM) model had a similar performance with an accuracy of 53%. The K-Nearest Neighbors (KNN) model provided the highest accuracy at 95%. The Decision Tree (DT) model and XGBoost (XGB) model also performed well, with accuracies of 92% and 93%, respectively. The Random Forest (RF) model outperformed all others with an accuracy of 97%. Overall, the Random Forest model performed the best among the tested models.
